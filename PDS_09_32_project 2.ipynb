# %%
import pandas as pd

#3 Load the datasets
term_test_1 = pd.read_csv(r"D:\project iict\term-test-1-result (1).csv")
term_test_2 = pd.read_csv(r"D:\project iict\term-test-2-result (1).csv")

# Display both dataframes
display(term_test_1)
display(term_test_2)

# Merge term_test_1 and term_test_2 on 'Registration Number'
merged_df = pd.merge(term_test_1, term_test_2, on="Registration Number")

#4 Clean up by keeping a single 'Name' column and rename the dataframe to marks
marks = merged_df.drop(columns=["Name_y"]).rename(columns={"Name_x": "Name"})

# Display the merged dataframe
print("Marks Dataframe:")
display(marks)

# Add a new column for Best Term Test Marks
marks["Best Marks"] = marks[["TT-1 Marks", "TT-2 Marks"]].max(axis=1)

# Add a new column for Average Term Test Marks
marks["Average Marks"] = marks[["TT-1 Marks", "TT-2 Marks"]].mean(axis=1)

# Display the updated dataframe
display(marks)

#5 Drop 'TT-1 Marks' and 'TT-2 Marks' columns
marks = marks.drop(columns=["TT-1 Marks", "TT-2 Marks"])

# Display the updated dataframe
display(marks)
#6 Calculating final marks
Final_marks_Dataset = pd.read_csv(r"D:\project iict\final marks.csv")
Final_marks_Dataset

Final_marks_Dataset["Final Marks"] = (Final_marks_Dataset["Term Final Marks"] * 0.7) + Final_marks_Dataset["Average Marks"] + Final_marks_Dataset["Attendance Marks"]
Final_marks_Dataset

#7
Final_marks_Dataset.to_csv("final_result.csv", index=False)

#8
# Step 1: Apply K-Means clustering (with 4 clusters)
kmeans = KMeans(n_clusters=4, random_state=42)
Final_marks_Dataset["Cluster"] = kmeans.fit_predict(Final_marks_Dataset[["Final Marks"]])

# Step 2: Visualize the clusters
plt.figure(figsize=(12, 8))
sns.scatterplot(data=Final_marks_Dataset, x="Registration Number", y="Final Marks", hue="Cluster", palette="viridis", s=100)
plt.title("K-Means Clustering of Final Marks")
plt.xlabel("Registration Number")
plt.ylabel("Final Marks")
plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#     Registration Number     Name  TT-1 Marks
# 0                  1001   Nasrin           1
# 1                  1002   Shorna          12
# 2                  1003  Sharmin          14
# 3                  1004    Sadia           2
# 4                  1005    Anika           3
# 5                  1006   Jannat          20
# 6                  1007     Rafi          14
# 7                  1008     Naim          17
# 8                  1009     Arif           0
# 9                  1010    Shuvo           3
# 10                 1011   Shorna           0
# 11                 1012     Mitu           1
# 12                 1013    Tumpa           4
# 13                 1014    Anika          12
# 14                 1015     Meem           2
# 15                 1016     Mitu          19
# 16                 1017    Israt          10
# 17                 1018    Habib          13
# 18                 1019   Badhon          17
# 19                 1020    Imran           9
# ...
